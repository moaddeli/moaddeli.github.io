# %% [markdown]
# # General

# %% [markdown]
# <div class="alert alert-success1">
#     <b>CS 20SI: Tensorflow for Deep Learning Research </b>:
#      <ul>
#       <li>
#           Stanford University Course
#       </li>
#       <li>
#           Winter quarter (2018)
#       </li>
#       <li>
#           <a href="http://web.stanford.edu/class/cs20si/">Links (Slides, Codes)</a>
#       </li>
#       <li>
#           <a href="https://github.com/chiphuyen/stanford-tensorflow-tutorials">Github Repo</a>
#       </li>
#
#     </ul>
# </div>

# %% [markdown]
# [link to another section](#General)
